# %% [markdown]
# <a href="https://colab.research.google.com/github/davidbau/rome/blob/gpt_stats/notebooks/statistics_of_GPT_states.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" align="left"/></a>&nbsp;or in a local notebook.

# %%
# %%bash
# !(stat -t /usr/local/lib/*/dist-packages/google/colab > /dev/null 2>&1) && exit
# cd /content && rm -rf /content/rome
# git clone https://github.com/davidbau/rome -b gpt_stats rome > install.log 2>&1
# pip install -r /content/rome/scripts/colab_reqs/rome.txt >> install.log 2>&1

# %%
IS_COLAB = False
try:
    import google.colab, torch, sys
    if not torch.cuda.is_available():
        print("Change runtime type to include a GPU.")
    sys.path.append('/content/rome')
    IS_COLAB = True
except:
    pass

# %% [markdown]
# # Statistics of GPT states
#
# Here we load GPT-2-XL and examine the statistics of its internal states.
#
# We are particularly interested in: how close are the output values to Gaussian.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# We build upon the ROME codebase.
#
# There is an `experiments.causal_trace` module that contains some useful utility functions for loading large transformer models in colab.

# %%
import os, re, json, math
import torch, numpy
from collections import defaultdict
from experiments.causal_trace import ModelAndTokenizer, predict_token

# %% [markdown]
# Now we load GPT-2-XL and a tokenizer, and show that it can complete a couple factual statements correctly.

# %%
torch.set_grad_enabled(False)
mt = ModelAndTokenizer('gpt2-xl', low_cpu_mem_usage=IS_COLAB)
#predict_token(mt, ['Shaquille O\'Neal plays the sport of',
#               'Megan Rapinoe plays the sport of'
#              ], return_p=True)

# %% [markdown]
# Now for some neutral text samples, we load some random texts from wikipedia.  Just a few (one batch for now).

# %%
from datasets import load_dataset
from baukit import TokenizedDataset, length_collation, flatten_masked_batch

def get_ds(ds_name='wikipedia', tokenizer=None, batch_tokens=None):
    raw_ds = load_dataset(
        ds_name,
        dict(wikitext="wikitext-103-raw-v1", wikipedia="20200501.en")[ds_name],
    )
    maxlen = mt.model.config.n_positions
    if batch_tokens is not None and batch_tokens < maxlen:
        maxlen = batch_tokens
    return TokenizedDataset(raw_ds["train"], tokenizer, maxlen=maxlen)
ds = get_ds(tokenizer=mt.tokenizer, ds_name='wikipedia')
# Out:
# Downloading:   0%|          | 0.00/4.24k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/6.87k [00:00<?, ?B/s]
# Reusing dataset wikipedia (/home/davidbau/.cache/huggingface/datasets/wikipedia/20200501.en/1.0.0/009f923d9b6dd00c00c8cdc7f408f2b47f45dd4f5fb7982a21f9448f4afbe475)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# Gather a large-scale sample of data.

# %%
import numpy
from baukit import module_names, TraceDict, pbar


num_universe_tokens = 100000000
num_sample_tokens =     1000000
selected_indexes = sorted(numpy.random.RandomState(1).choice(num_universe_tokens, num_sample_tokens, replace=False))
dirname = f'gpt_2_xl_sample/{num_sample_tokens}_of_{num_universe_tokens}'

batch_tokens = mt.model.config.n_positions * 3
loader = torch.utils.data.DataLoader(
    ds, batch_size=100, collate_fn=length_collation(batch_tokens),
    pin_memory=True, num_workers=8)

from collections import defaultdict

class SampleCollector:
    def __init__(self, sample_size):
        self.data = {}
        self.sample_size = sample_size
        self.size = 0
        
    def add(self, data):
        assert not self.full()
        batch_size = 0
        for k, v in data.items():
            if k not in self.data:
                if torch.is_tensor(v):
                    self.data[k] = torch.zeros((self.sample_size,) + v.shape[1:], dtype=v.dtype)
                else:
                    self.data[k] = []
            batch_size = len(v)
            trunc_size = min(batch_size, self.sample_size - self.size)
            if torch.is_tensor(v):
                self.data[k][self.size:self.size+trunc_size] = v[:trunc_size]
            else:
                self.data[k].extend(v[:trunc_size])
        self.size += trunc_size
        
    def full(self):
        return self.size >= self.sample_size

    def save(self, directory):
        os.makedirs(directory, exist_ok=True)
        for k, v in self.data.items():
            if torch.is_tensor(v):
                numpy.save(f'{directory}/{k}.npy', v.numpy())
            else:
                with open(f'{directory}/{k}.json', 'w') as f:
                    json.dump(v, f, indent=0)
                    
def untuple(d):
    if isinstance(d, tuple):
        return d[0]
    return d
                    
# trace_layer_names = [n for n in module_names(mt.model) if re.match(r'.*\.\d+(\.mlp|\.attn|)?$', n)]
trace_layer_names = ['transformer.h.15.mlp.c_proj']
    
collector = SampleCollector(num_sample_tokens)

current_selection_index = 0
current_token_number = 0
current_batch_number = 0

for batch_group in pbar(loader, total=len(selected_indexes)):
    for batch in batch_group:
        mask = batch['attention_mask']
        input_ids = batch['input_ids']
        batch_size = mask.sum().item()
        # Optimization: nothing selected in this batch
        batch_number = current_batch_number
        start_of_batch = current_token_number
        end_of_batch = current_token_number + batch_size
        start_index = current_selection_index
        current_indexes = []
        while (current_selection_index < len(selected_indexes) and
               selected_indexes[current_selection_index] < end_of_batch):
            current_indexes.append(selected_indexes[current_selection_index].item() - start_of_batch)
            current_selection_index += 1
        current_token_number += batch_size
        current_batch_number += 1
        if not current_indexes:
            continue
        # Select some tokens
        nzi = mask.nonzero()[current_indexes]
        batch_indexes = nzi.t().numpy()
        cuda_batch = {k: v.cuda() for k, v in batch.items()}
        with TraceDict(mt.model, trace_layer_names, retain_input=True) as hidden_state:
            results = mt.model(**cuda_batch)
        data = {f'{k}.output': untuple(v.output)[batch_indexes].cpu() for k, v in hidden_state.items()}
        data.update({f'{k}.input': untuple(v.input)[batch_indexes].cpu() for k, v in hidden_state.items()})
        data['text'] = [mt.tokenizer.decode(input_ids[j,:t+1]) for j, t in batch_indexes.T]
        data['index'] = torch.cat([torch.full((len(nzi), 1), batch_number, dtype=torch.long), nzi], dim=1)
        collector.add(data)
        pbar.update(current_selection_index - start_index)
        if collector.full():
            break
    if collector.full():
        break
collector.save(dirname)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]

# %%
ls -l gpt_2_xl_sample/1000000_of_100000000
# Out:
# total 32833952
# -rw-rw-r-- 1 davidbau davidbau    24000128 Mar 27 19:45 index.npy
# -rw-rw-r-- 1 davidbau davidbau  1597943514 Mar 27 19:45 text.json
# -rw-rw-r-- 1 davidbau davidbau 25600000128 Mar 27 19:45 transformer.h.15.mlp.c_proj.input.npy
# -rw-rw-r-- 1 davidbau davidbau  6400000128 Mar 27 19:45 transformer.h.15.mlp.c_proj.output.npy

# %% [markdown]
# Let's create a tool that lets you see the predictions from a given prefix of the sentence.
#
# You can use this to see that the GPT is operating correctly.
#
# We will also use TraceDict to trace all the internal layers of the GPT network.

# %%
from baukit import Textarea, Range, show, PlotWidget, TraceDict, module_names
import re

trace_layer_names = [n for n in module_names(mt.model) if re.match(r'.*\.\d+(\.mlp|\.attn|)?$', n)]
trace_layer_names = sum(
    ([f'transformer.h.{n}', f'transformer.h.{n}.mlp', f'transformer.h.{n}.attn']
    for n in [0, 15, 30, 45]), [])

# Grab the 0th batch in the batch-grouop
input = {k: v.cuda() for k, v in batch_group[0].items()}

with TraceDict(mt.model, trace_layer_names) as hidden_state:
    results = mt.model(**input)
all_hs = {k: v.output[0].cpu()
          if isinstance(v.output, tuple) else v.output.cpu()
          for k, v in hidden_state.items()
         }
layername = 'transformer.h.15'
hs = all_hs[layername]
logits = results['logits'][0].cpu()
tokens = input['input_ids'][0]


def redraw_text():
    tb.value = mt.tokenizer.decode(tokens[:ra.value+1])

    
def plot_predictions(fig, index=1, k=20):
    [ax] = fig.axes
    ax.clear()
    probs = torch.softmax(logits[index], dim=0)
    top_prob, top_tok = torch.topk(probs, dim=0, k=k)
    x = range(len(top_prob))
    labels = [mt.tokenizer.decode(t) for t in top_tok]
    ax.set_ylim(0,1)
    ax.bar(x, top_prob)
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=90)


ra = Range(min=0, max=min(200, len(tokens)), value=0).on('value', redraw_text)
tb = Textarea()
plot = PlotWidget(plot_predictions, index=ra.prop('value'))
show([show.style(alignItems='flex-start'), [[ra, [show.style(width='500px', height='300px'), tb]], plot]])
# Out:
# <div style="display:inline-flex;flex-flow:row wrap;gap:3px;align-items:center"><div style="display:flex;flex:1;flex-flow:column;gap:3px"><div style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:flex-start"><div style="display:flex;flex:1;flex-flow:column;gap:3px"><input id="_140214374528048_1" type="range" value="0" min="0" max="200" step="1" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center"><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# chan.retry = setInterval(() => {
# if (chan.retries) { chan.retries -= 1; chan.comm.open(); }
# else { clearInterval(chan.retry); chan.retry = null; }
# }, 2000);
# }
# return chan;
# }
# function recvFromPython(obj_id, fn) {
# getChan(obj_id).push(fn);
# }
# function sendToPython(obj_id, ...args) {
# var comm = getChan(obj_id).comm;
# if (comm) { comm.send(args); }
# }
# class Model {
# constructor(obj_id, init) {
# this._id = obj_id;
# this._listeners = {};
# this._data = Object.assign({}, init);
# this._sent = {};
# recvFromPython(this._id, (name, value) => {
# this._data[name] = value;
# var e = new Event(name); e.value = value;
# if (this._listeners.hasOwnProperty(name)) {
# this._listeners[name].forEach((fn) => { fn(e); });
# }
# if (this._sent[name]) {
# value = this._sent[name];
# delete this._sent[name];
# if (value.length) {
# value = value[0];
# this.set_soon(name, value);
# }
# }
# })
# }
# trigger(name, value) {
# sendToPython(this._id, name, value);
# }
# get(name) {
# return this._data[name];
# }
# set(name, value) {
# delete this._sent[name];
# this.trigger(name, value);
# }
# set_soon(name, value) {
# if (!this._sent.hasOwnProperty(name)) {
# this._sent[name] = [];
# this.trigger(name, value);
# } else {
# this._sent[name] = [value];
# }
# }
# on(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = [];
# }
# this._listeners[n].push(fn);
# });
# }
# off(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!fn) {
# delete this._listeners[n];
# } else if (this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = this._listeners[n].filter(
# (e) => { return e !== fn; });
# }
# });
# }
# }
#
# var model = new Model("140214374528048", {"style": null, "value": 0, "min": 0, "max": 200, "step": 1});
# var element = document.getElementById("_140214374528048_1");
# model.on('write', (ev) => {
# var dummy = document.createElement('div');
# dummy.innerHTML = ev.value.trim();
# dummy.childNodes.forEach((item) => {
# element.parentNode.insertBefore(item, element);
# });
# });
# function upd(a) { return (e) => { for (k in e.value) {
# element[a][k] = e.value[k];
# }}}
# model.on('style', upd('style'));
# model.on('style', upd('style'));
# model.on('data', upd('dataset'));
#
# element.addEventListener('input', (e) => {
# model.set_soon('value', parseFloat(element.value));
# });
# element.addEventListener('change', (e) => {
# model.set('value', parseFloat(element.value));
# });
# model.on('value', (e) => {
# if (!element.matches(':active')) {
# element.value = e.value;
# }
# })
# })();</script><div style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center"><textarea id="_140220549558624_1" style="display:flex;flex:1;flex-flow:column;gap:3px;width:500px;height:300px"></textarea><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# chan.retry = setInterval(() => {
# if (chan.retries) { chan.retries -= 1; chan.comm.open(); }
# else { clearInterval(chan.retry); chan.retry = null; }
# }, 2000);
# }
# return chan;
# }
# function recvFromPython(obj_id, fn) {
# getChan(obj_id).push(fn);
# }
# function sendToPython(obj_id, ...args) {
# var comm = getChan(obj_id).comm;
# if (comm) { comm.send(args); }
# }
# class Model {
# constructor(obj_id, init) {
# this._id = obj_id;
# this._listeners = {};
# this._data = Object.assign({}, init);
# this._sent = {};
# recvFromPython(this._id, (name, value) => {
# this._data[name] = value;
# var e = new Event(name); e.value = value;
# if (this._listeners.hasOwnProperty(name)) {
# this._listeners[name].forEach((fn) => { fn(e); });
# }
# if (this._sent[name]) {
# value = this._sent[name];
# delete this._sent[name];
# if (value.length) {
# value = value[0];
# this.set_soon(name, value);
# }
# }
# })
# }
# trigger(name, value) {
# sendToPython(this._id, name, value);
# }
# get(name) {
# return this._data[name];
# }
# set(name, value) {
# delete this._sent[name];
# this.trigger(name, value);
# }
# set_soon(name, value) {
# if (!this._sent.hasOwnProperty(name)) {
# this._sent[name] = [];
# this.trigger(name, value);
# } else {
# this._sent[name] = [value];
# }
# }
# on(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = [];
# }
# this._listeners[n].push(fn);
# });
# }
# off(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!fn) {
# delete this._listeners[n];
# } else if (this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = this._listeners[n].filter(
# (e) => { return e !== fn; });
# }
# });
# }
# }
#
# var model = new Model("140220549558624", {"style": {"display": "inline-block"}, "value": ""});
# var element = document.getElementById("_140220549558624_1");
# model.on('write', (ev) => {
# var dummy = document.createElement('div');
# dummy.innerHTML = ev.value.trim();
# dummy.childNodes.forEach((item) => {
# element.parentNode.insertBefore(item, element);
# });
# });
# function upd(a) { return (e) => { for (k in e.value) {
# element[a][k] = e.value[k];
# }}}
# model.on('style', upd('style'));
# model.on('style', upd('style'));
# model.on('data', upd('dataset'));
#
# element.value = model.get('value');
# element.addEventListener('keydown', (e) => {
# if (e.code == 'Enter') {
# model.set('value', element.value);
# }
# });
# element.addEventListener('blur', (e) => {
# model.set('value', element.value);
# });
# model.on('value', (ev) => {
# element.value = model.get('value');
# });
# })();</script></div></div><img id="_140214374530928_1" src="data:image/png;base64,..." style="display:flex;flex:1;flex-flow:column;gap:3px;margin:0px"><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# chan.retry = setInterval(() => {
# if (chan.retries) { chan.retries -= 1; chan.comm.open(); }
# else { clearInterval(chan.retry); chan.retry = null; }
# }, 2000);
# }
# return chan;
# }
# function recvFromPython(obj_id, fn) {
# getChan(obj_id).push(fn);
# }
# function sendToPython(obj_id, ...args) {
# var comm = getChan(obj_id).comm;
# if (comm) { comm.send(args); }
# }
# class Model {
# constructor(obj_id, init) {
# this._id = obj_id;
# this._listeners = {};
# this._data = Object.assign({}, init);
# this._sent = {};
# recvFromPython(this._id, (name, value) => {
# this._data[name] = value;
# var e = new Event(name); e.value = value;
# if (this._listeners.hasOwnProperty(name)) {
# this._listeners[name].forEach((fn) => { fn(e); });
# }
# if (this._sent[name]) {
# value = this._sent[name];
# delete this._sent[name];
# if (value.length) {
# value = value[0];
# this.set_soon(name, value);
# }
# }
# })
# }
# trigger(name, value) {
# sendToPython(this._id, name, value);
# }
# get(name) {

# %% [markdown]
# Now, let's take a look at the distributions of hidden states.
#
# Here is the UI code.  Basically we will:
#
#   1. grab a sample of 2000 tokens from the batch
#   2. examine the hidden state at a particular layer all those random tokens
#   3. within this sample we plot the distribution of cosine similiarities between pairs
#
# The layer to examine is selectable.
#
# We can explore quantiles and examine the raw token pairs with a given similarity with a slider.

# %%
import numpy, random
from baukit import Menu

def show_gpt_state_distribution():
    attn_mask = input['attention_mask']
    input_ids = input['input_ids']
    
    def decode(i, t, prefix_len=10):
        if t+1 < input_ids.shape[1]:
            next_token = f'[{mt.tokenizer.decode(input_ids[i, t+1])}]'
        else:
            next_token = '<END>'
        return mt.tokenizer.decode(input_ids[i][max(0, t-prefix_len+1):t+1]) + next_token
        
    all_indexes = torch.tensor(numpy.array(numpy.unravel_index(range(input_ids.numel()), input_ids.shape)).T)
    flat_indexes = flatten_masked_batch(all_indexes, attn_mask)
    sample_size = 2000
    sample = random.sample(range(len(flat_indexes)), sample_size)
    inds = flat_indexes[sample]    

    
    num_pairs = (sample_size // 2) ** 2
    ra = Range(min=0, max=num_pairs - 1, value=num_pairs // 2)
    def drawme(plt, bins=200, to_show=num_pairs // 2, layername=layername):
        ax = plt.axes[0]
        ax.clear()
        ax.set_title(f'Cosine similarity between {layername} pairs over a sample of {sample_size} wiki texts')
        
        flat = flatten_masked_batch(all_hs[layername], attn_mask)
        d = flat[sample]

        # Mean-center and normalize before computing angles.
        d = d - d.mean(dim=1, keepdim=True)
        d = d / d.norm(dim=1, keepdim=True)
        angles = d[:len(d) // 2] @ d[len(d) // 2:].t()
        pairs = [(x, y) for x in range(len(d) // 2) for y in range(len(d) // 2, len(d))]
        sorted_angles, sorted_indexes = angles.view(-1).sort(dim=0)
        
        ax.hist(angles.view(-1).numpy(), bins=torch.linspace(-1, 1, bins), density=True)
        # ax.hist(angles.view(-1).numpy(), bins=bins, density=True)
        ax.set_yscale('log')
        x, y = pairs[sorted_indexes[to_show]]
        [xi, xt], [yi, yt] = inds[x], inds[y]
        angle = angles[x, y - len(d) // 2]
        ax.axvline(angle, color='red')
        ta.value = f'''\
similarity {angle:.3g}: (sample {x}, sample {y})
--- sample {x}:
{decode(xi, xt)}
--- sample {y}:
{decode(yi, yt)}'''
    ch = Menu(choices=trace_layer_names, selection=layername)
    ta = Textarea()
    plot = PlotWidget(drawme, to_show=ra.prop('value'), figsize=(10,3), layername=ch.prop('selection'), dpi=100)
    show([[show.style(textAlign='right'), 'Layer:', ch],
          [show.style(textAlign='right'), 'Quantile:', ra],
          plot, show.attr(rows=10), ta])
# show_gpt_state_distribution()

# %% [markdown]
# To have a baseline to compare with, we do the same with an normal Gaussian distribution of the same dimensionality.
#
# We note that if we actually reduce the dimensionality, we can get histograms that more resemble the true data distributions, so we provide a slider for adjusting the dimensionailty of the sample

# %%
import math
def show_gaussian_distribution():
    raw_data = torch.randn(2048, 1600)
    num_pairs = (len(raw_data) // 2) ** 2
    num_dimensions = raw_data.shape[1]
    
    def drawme(plt, bins=200, to_show=num_pairs // 2, dimensions=num_dimensions):
        ax = plt.axes[0]
        ax.clear()
        ax.set_title(f'Cosine similarity between pairs in a {dimensions}-dimensional Gaussian')
        d = raw_data.clone()
        d[:,dimensions:] = 0
        d = d / d.norm(dim=1, keepdim=True)
        angles = d[:len(d) // 2] @ d[len(d) // 2:].t()
        pairs = [(x, y) for x in range(len(d) // 2) for y in range(len(d) - len(d) // 2)]
        sorted_angles, sorted_indexes = angles.view(-1).sort(dim=0)
        x, y = pairs[sorted_indexes[to_show]]
        angle = angles[x, y]
        
        ax.hist(angles.view(-1).numpy(), bins=torch.linspace(-1, 1, bins), density=True)
        ax.set_yscale('log')
        ax.axvline(angle, color='red')
        ta.value = f'dimensions: {dimensions}\nsimilarity: {angle:.3g}: ({x}, {y + len(d) // 2})'
    rd = Range(min=0, max=num_dimensions, value=num_dimensions)
    ra = Range(min=0, max=num_pairs - 1, value=num_pairs // 2)
    ta = Textarea()
    plot = PlotWidget(drawme, to_show=ra.prop('value'), dimensions=rd.prop('value'), figsize=(10,3), dpi=100)
    show([[show.style(textAlign='right'), 'Dimensions:', rd],
          [show.style(textAlign='right'), 'Quantile:', ra],
          plot, show.attr(rows=2), ta])

# %% [markdown]
# Now we wish to ask: how close is the distribution of transformer hidden states to Gaussian?
#
# We will take a sample of them, and see.

# %%
show_gaussian_distribution()
show_gpt_state_distribution()
# Out:
# <div style="display:inline-flex;flex-flow:row wrap;gap:3px;align-items:center"><div style="display:flex;flex:1;flex-flow:column;gap:3px"><div style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center"><div style="display:flex;flex:1;flex-flow:column;gap:3px;text-align:right">Dimensions:</div><input id="_140214317995728_1" type="range" value="1600" min="0" max="1600" step="1" style="display:flex;flex:1;flex-flow:column;gap:3px"><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# chan.retry = setInterval(() => {
# if (chan.retries) { chan.retries -= 1; chan.comm.open(); }
# else { clearInterval(chan.retry); chan.retry = null; }
# }, 2000);
# }
# return chan;
# }
# function recvFromPython(obj_id, fn) {
# getChan(obj_id).push(fn);
# }
# function sendToPython(obj_id, ...args) {
# var comm = getChan(obj_id).comm;
# if (comm) { comm.send(args); }
# }
# class Model {
# constructor(obj_id, init) {
# this._id = obj_id;
# this._listeners = {};
# this._data = Object.assign({}, init);
# this._sent = {};
# recvFromPython(this._id, (name, value) => {
# this._data[name] = value;
# var e = new Event(name); e.value = value;
# if (this._listeners.hasOwnProperty(name)) {
# this._listeners[name].forEach((fn) => { fn(e); });
# }
# if (this._sent[name]) {
# value = this._sent[name];
# delete this._sent[name];
# if (value.length) {
# value = value[0];
# this.set_soon(name, value);
# }
# }
# })
# }
# trigger(name, value) {
# sendToPython(this._id, name, value);
# }
# get(name) {
# return this._data[name];
# }
# set(name, value) {
# delete this._sent[name];
# this.trigger(name, value);
# }
# set_soon(name, value) {
# if (!this._sent.hasOwnProperty(name)) {
# this._sent[name] = [];
# this.trigger(name, value);
# } else {
# this._sent[name] = [value];
# }
# }
# on(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = [];
# }
# this._listeners[n].push(fn);
# });
# }
# off(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!fn) {
# delete this._listeners[n];
# } else if (this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = this._listeners[n].filter(
# (e) => { return e !== fn; });
# }
# });
# }
# }
#
# var model = new Model("140214317995728", {"style": null, "value": 1600, "min": 0, "max": 1600, "step": 1});
# var element = document.getElementById("_140214317995728_1");
# model.on('write', (ev) => {
# var dummy = document.createElement('div');
# dummy.innerHTML = ev.value.trim();
# dummy.childNodes.forEach((item) => {
# element.parentNode.insertBefore(item, element);
# });
# });
# function upd(a) { return (e) => { for (k in e.value) {
# element[a][k] = e.value[k];
# }}}
# model.on('style', upd('style'));
# model.on('style', upd('style'));
# model.on('data', upd('dataset'));
#
# element.addEventListener('input', (e) => {
# model.set_soon('value', parseFloat(element.value));
# });
# element.addEventListener('change', (e) => {
# model.set('value', parseFloat(element.value));
# });
# model.on('value', (e) => {
# if (!element.matches(':active')) {
# element.value = e.value;
# }
# })
# })();</script></div><div style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center"><div style="display:flex;flex:1;flex-flow:column;gap:3px;text-align:right">Quantile:</div><input id="_140214317996112_1" type="range" value="524288" min="0" max="1048575" step="1" style="display:flex;flex:1;flex-flow:column;gap:3px"><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# chan.retry = setInterval(() => {
# if (chan.retries) { chan.retries -= 1; chan.comm.open(); }
# else { clearInterval(chan.retry); chan.retry = null; }
# }, 2000);
# }
# return chan;
# }
# function recvFromPython(obj_id, fn) {
# getChan(obj_id).push(fn);
# }
# function sendToPython(obj_id, ...args) {
# var comm = getChan(obj_id).comm;
# if (comm) { comm.send(args); }
# }
# class Model {
# constructor(obj_id, init) {
# this._id = obj_id;
# this._listeners = {};
# this._data = Object.assign({}, init);
# this._sent = {};
# recvFromPython(this._id, (name, value) => {
# this._data[name] = value;
# var e = new Event(name); e.value = value;
# if (this._listeners.hasOwnProperty(name)) {
# this._listeners[name].forEach((fn) => { fn(e); });
# }
# if (this._sent[name]) {
# value = this._sent[name];
# delete this._sent[name];
# if (value.length) {
# value = value[0];
# this.set_soon(name, value);
# }
# }
# })
# }
# trigger(name, value) {
# sendToPython(this._id, name, value);
# }
# get(name) {
# return this._data[name];
# }
# set(name, value) {
# delete this._sent[name];
# this.trigger(name, value);
# }
# set_soon(name, value) {
# if (!this._sent.hasOwnProperty(name)) {
# this._sent[name] = [];
# this.trigger(name, value);
# } else {
# this._sent[name] = [value];
# }
# }
# on(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = [];
# }
# this._listeners[n].push(fn);
# });
# }
# off(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!fn) {
# delete this._listeners[n];
# } else if (this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = this._listeners[n].filter(
# (e) => { return e !== fn; });
# }
# });
# }
# }
#
# var model = new Model("140214317996112", {"style": null, "value": 524288, "min": 0, "max": 1048575, "step": 1});
# var element = document.getElementById("_140214317996112_1");
# model.on('write', (ev) => {
# var dummy = document.createElement('div');
# dummy.innerHTML = ev.value.trim();
# dummy.childNodes.forEach((item) => {
# element.parentNode.insertBefore(item, element);
# });
# });
# function upd(a) { return (e) => { for (k in e.value) {
# element[a][k] = e.value[k];
# }}}
# model.on('style', upd('style'));
# model.on('style', upd('style'));
# model.on('data', upd('dataset'));
#
# element.addEventListener('input', (e) => {
# model.set_soon('value', parseFloat(element.value));
# });
# element.addEventListener('change', (e) => {
# model.set('value', parseFloat(element.value));
# });
# model.on('value', (e) => {
# if (!element.matches(':active')) {
# element.value = e.value;
# }
# })
# })();</script></div><img id="_140214318033120_1" src="data:image/png;base64,..." style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center;margin:0px"><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# chan.retry = setInterval(() => {
# if (chan.retries) { chan.retries -= 1; chan.comm.open(); }
# else { clearInterval(chan.retry); chan.retry = null; }
# }, 2000);
# }
# return chan;
# }
# function recvFromPython(obj_id, fn) {
# getChan(obj_id).push(fn);
# }
# function sendToPython(obj_id, ...args) {
# var comm = getChan(obj_id).comm;
# if (comm) { comm.send(args); }
# }
# class Model {
# constructor(obj_id, init) {
# this._id = obj_id;
# this._listeners = {};
# this._data = Object.assign({}, init);
# this._sent = {};
# recvFromPython(this._id, (name, value) => {
# this._data[name] = value;
# var e = new Event(name); e.value = value;
# if (this._listeners.hasOwnProperty(name)) {
# this._listeners[name].forEach((fn) => { fn(e); });
# }
# if (this._sent[name]) {
# value = this._sent[name];
# delete this._sent
# <div style="display:inline-flex;flex-flow:row wrap;gap:3px;align-items:center"><div style="display:flex;flex:1;flex-flow:column;gap:3px"><div style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center"><div style="display:flex;flex:1;flex-flow:column;gap:3px;text-align:right">Layer:</div><form id="_140214416499136_1" style="display:flex;flex:1;flex-flow:column;gap:3px"><select name="menu" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center"><option value="transformer.h.0" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.0</option><option value="transformer.h.0.mlp" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.0.mlp</option><option value="transformer.h.0.attn" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.0.attn</option><option selected value="transformer.h.15" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.15</option><option value="transformer.h.15.mlp" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.15.mlp</option><option value="transformer.h.15.attn" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.15.attn</option><option value="transformer.h.30" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.30</option><option value="transformer.h.30.mlp" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.30.mlp</option><option value="transformer.h.30.attn" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.30.attn</option><option value="transformer.h.45" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.45</option><option value="transformer.h.45.mlp" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.45.mlp</option><option value="transformer.h.45.attn" style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center">transformer.h.45.attn</option></select></form><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# chan.retry = setInterval(() => {
# if (chan.retries) { chan.retries -= 1; chan.comm.open(); }
# else { clearInterval(chan.retry); chan.retry = null; }
# }, 2000);
# }
# return chan;
# }
# function recvFromPython(obj_id, fn) {
# getChan(obj_id).push(fn);
# }
# function sendToPython(obj_id, ...args) {
# var comm = getChan(obj_id).comm;
# if (comm) { comm.send(args); }
# }
# class Model {
# constructor(obj_id, init) {
# this._id = obj_id;
# this._listeners = {};
# this._data = Object.assign({}, init);
# this._sent = {};
# recvFromPython(this._id, (name, value) => {
# this._data[name] = value;
# var e = new Event(name); e.value = value;
# if (this._listeners.hasOwnProperty(name)) {
# this._listeners[name].forEach((fn) => { fn(e); });
# }
# if (this._sent[name]) {
# value = this._sent[name];
# delete this._sent[name];
# if (value.length) {
# value = value[0];
# this.set_soon(name, value);
# }
# }
# })
# }
# trigger(name, value) {
# sendToPython(this._id, name, value);
# }
# get(name) {
# return this._data[name];
# }
# set(name, value) {
# delete this._sent[name];
# this.trigger(name, value);
# }
# set_soon(name, value) {
# if (!this._sent.hasOwnProperty(name)) {
# this._sent[name] = [];
# this.trigger(name, value);
# } else {
# this._sent[name] = [value];
# }
# }
# on(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = [];
# }
# this._listeners[n].push(fn);
# });
# }
# off(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!fn) {
# delete this._listeners[n];
# } else if (this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = this._listeners[n].filter(
# (e) => { return e !== fn; });
# }
# });
# }
# }
#
# var model = new Model("140214416499136", {"style": null, "choices": ["transformer.h.0", "transformer.h.0.mlp", "transformer.h.0.attn", "transformer.h.15", "transformer.h.15.mlp", "transformer.h.15.attn", "transformer.h.30", "transformer.h.30.mlp", "transformer.h.30.attn", "transformer.h.45", "transformer.h.45.mlp", "transformer.h.45.attn"], "selection": "transformer.h.15"});
# var element = document.getElementById("_140214416499136_1");
# model.on('write', (ev) => {
# var dummy = document.createElement('div');
# dummy.innerHTML = ev.value.trim();
# dummy.childNodes.forEach((item) => {
# element.parentNode.insertBefore(item, element);
# });
# });
# function upd(a) { return (e) => { for (k in e.value) {
# element[a][k] = e.value[k];
# }}}
# model.on('style', upd('style'));
# model.on('style', upd('style'));
# model.on('data', upd('dataset'));
#
# function esc(unsafe) {
# return unsafe.replace(/&/g, "&amp;").replace(/</g, "&lt;")
# .replace(/>/g, "&gt;").replace(/"/g, "&quot;");
# }
# function render() {
# var selection = model.get('selection');
# var lines = model.get('choices').map((c) => {
# return '<option value="' + esc(''+c) + '"' +
# (c == selection ? ' selected' : '') +
# '>' + esc(''+c) + '</option>';
# });
# element.menu.innerHTML = lines.join('\n');
# }
# model.on('selection', (ev) => {
# [...element.querySelectorAll('option')].forEach((e) => {
# e.selected = (e.value == ev.value);
# })
# });
# element.addEventListener('change', (e) => {
# model.set('selection', element.menu.value);
# });
# })();</script></div><div style="display:flex;flex:1;flex-flow:row wrap;gap:3px;align-items:center"><div style="display:flex;flex:1;flex-flow:column;gap:3px;text-align:right">Quantile:</div><input id="_140207562362688_1" type="range" value="500000" min="0" max="999999" step="1" style="display:flex;flex:1;flex-flow:column;gap:3px"><script>(function() {
# function getChan(obj_id) {
# var cname = "comm_" + obj_id;
# if (!window[cname]) { window[cname] = []; }
# var chan = window[cname];
# if (!chan.comm && Jupyter.notebook.kernel) {
# chan.comm = Jupyter.notebook.kernel.comm_manager.new_comm(cname, {});
# chan.comm.on_msg((ev) => {
# if (chan.retry) { clearInterval(chan.retry); chan.retry = null; }
# if (ev.content.data == 'ok') { return; }
# var args = ev.content.data.slice(1);
# for (fn of chan) { fn.apply(null, args); }
# });
# chan.retries = 5;
# chan.retry = setInterval(() => {
# if (chan.retries) { chan.retries -= 1; chan.comm.open(); }
# else { clearInterval(chan.retry); chan.retry = null; }
# }, 2000);
# }
# return chan;
# }
# function recvFromPython(obj_id, fn) {
# getChan(obj_id).push(fn);
# }
# function sendToPython(obj_id, ...args) {
# var comm = getChan(obj_id).comm;
# if (comm) { comm.send(args); }
# }
# class Model {
# constructor(obj_id, init) {
# this._id = obj_id;
# this._listeners = {};
# this._data = Object.assign({}, init);
# this._sent = {};
# recvFromPython(this._id, (name, value) => {
# this._data[name] = value;
# var e = new Event(name); e.value = value;
# if (this._listeners.hasOwnProperty(name)) {
# this._listeners[name].forEach((fn) => { fn(e); });
# }
# if (this._sent[name]) {
# value = this._sent[name];
# delete this._sent[name];
# if (value.length) {
# value = value[0];
# this.set_soon(name, value);
# }
# }
# })
# }
# trigger(name, value) {
# sendToPython(this._id, name, value);
# }
# get(name) {
# return this._data[name];
# }
# set(name, value) {
# delete this._sent[name];
# this.trigger(name, value);
# }
# set_soon(name, value) {
# if (!this._sent.hasOwnProperty(name)) {
# this._sent[name] = [];
# this.trigger(name, value);
# } else {
# this._sent[name] = [value];
# }
# }
# on(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = [];
# }
# this._listeners[n].push(fn);
# });
# }
# off(name, fn) {
# name.split(/\s+/).forEach((n) => {
# if (!fn) {
# delete this._listeners[n];
# } else if (this._listeners.hasOwnProperty(n)) {
# this._listeners[n] = this._listeners[n].filter

# %% [markdown]
# Conclusions:
#
#  * Hidden states and Attn output distributions are far from Gaussian.
#  * But MLP outputs seem closer to Gaussian.
#  * But they also behave as if they have lower dimension than the full dimensionality.
